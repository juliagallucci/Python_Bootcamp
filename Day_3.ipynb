# %% [markdown]
# <a href="https://colab.research.google.com/github/joannafan0518/Python_Bootcamp/blob/day-3-exercise/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 3 Exercises
# ## Control flow

# %% [markdown]
# #### 1. Write a conditional that prints different messages if a bank account balance is below 3,000, between 3,000 and 10,000, or over 10,000.

# %%
# Your code goes here
def bank_account_balance():
  balance = float(input("What is your bank account balance?"))
  if balance < 3000:
    print("Your balance is below $3,000")
  elif balance >= 3000 and balance <= 10000:
    print("Your balance is between $3,000 and $10,000")
  else:
    print("Your balance is over $10,000")

# %%
bank_account_balance()
# Out:
# What is your bank account balance?1000
# Your balance is below $3,000

# %% [markdown]
# #### 2. Create a list, `books`, containing the following items: 'War and Peace', 'Pride and Prejudice', 'Mockingjay', 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin'.
#
# Then using slicing or indexing, create the following:
# - An empty list
# - The last item of books
# - List of three items: 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin'.

# %%
# Your code goes here

books = ['War and Peace', 'Pride and Prejudice', 'Mockingjay', 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']

empty_list = books[0:0]
print(empty_list)
# Out:
# []

# %%
last_item = books[-1]
print(last_item)
# Out:
# Yevgeniy Onegin

# %%
three_books = books[3:]
print(three_books)
# Out:
# ['Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']

# %% [markdown]
# Using list methods:
#
# - Remove 'Pride and Prejudice' from the list.
# - Insert 'Harry Potter and the Chamber of Secrets' after 'Mockingjay'.

# %%
# Your code goes here

books.remove('Pride and Prejudice')
print(books)
# Out:
# ['War and Peace', 'Mockingjay', 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']

# %%
books.insert(2, 'Harry Potter and the Chamber of Secrets')
print(books)
# Out:
# ['War and Peace', 'Mockingjay', 'Harry Potter and the Chamber of Secrets', 'Three Musketeers', 'The Adventures of Robinson Crusoe', 'Yevgeniy Onegin']

# %% [markdown]
# #### 3. Given the list `people`, sort it by people's first name, last name and age. Store the sorted lists as by_first_name, by_last_name, and by_age, respectively.
#
# people = [('Mark', 'Harrison', 56), ('Ken', 'Wolseley', 23), ('Emily', 'Robinson', 77)]

# %%
# Your code goes here

people = [('Mark', 'Harrison', 56), ('Ken', 'Wolseley', 23), ('Emily', 'Robinson', 77)]

def get_first_name (person):
    return person[0]

by_first_name = sorted (people, key = get_first_name)
print(by_first_name)
# Out:
# [('Emily', 'Robinson', 77), ('Ken', 'Wolseley', 23), ('Mark', 'Harrison', 56)]

# %%
def get_last_name (person):
    return person[1]

by_last_name = sorted (people, key = get_last_name)
print(by_last_name)
# Out:
# [('Mark', 'Harrison', 56), ('Emily', 'Robinson', 77), ('Ken', 'Wolseley', 23)]

# %%
def get_age (person):
    return person[2]

by_age = sorted (people, key = get_age)
print(by_age)
# Out:
# [('Ken', 'Wolseley', 23), ('Mark', 'Harrison', 56), ('Emily', 'Robinson', 77)]

# %% [markdown]
# #### 4. Write a function called `dict_intersect` that takes two dictionaries, d1 and d2, as arguments and returns a set that contains only the keys found in both of the original dictionaries.

# %%
# Your code goes here

def dict_intersect(d1, d2):
  return set(d1.keys()) & set(d2.keys())

# %%
d1 = {'a': 1, 'b': 2, 'c': 3}
d2 = {'b': 4, 'c': 5, 'd': 6}

dict_intersect(d1, d2)
# Out:
# {'b', 'c'}

# %% [markdown]
# ## Reading and Writing

# %% [markdown]
# #### 1. Using `w`, create a file called fruits.txt and write the string "tangerines" to it.

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir
# Out:
# <function posix.listdir(path=None)>

# %%
os.chdir
# Out:
# <function posix.chdir(path)>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks')

# %%
# Your code goes here
with open("fruits.txt", "w") as file:
    file.write("tangerines")

# %% [markdown]
# #### 2. Next, use a to append the string "dragon fruit" to the file on a new line.

# %%
# Your code goes here
with open("fruits.txt", "a") as file:
    file.write("\n")
    file.write("dragon fruit")

# %% [markdown]
# #### 3. Finally, use the `r` mode to read and print the entire file.

# %%
# Your code goes here
with open("fruits.txt", "r") as file:
    print(file.read())
# Out:
# tangerines
# dragon fruit
