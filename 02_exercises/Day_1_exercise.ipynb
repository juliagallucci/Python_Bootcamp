# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5

# %% [markdown]
# *The expression involves an integer and a float and evaluates to a float 20.0.*

# %%
9 / 2

# %% [markdown]
# *This expression involves two integers and using the division operator results in the float 4.5*

# %%
1.5 * 2 >= 7 - 3

# %% [markdown]
# *This expression involves one float (1.5) and integers. The end result is a boolean (false)*

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4

# %% [markdown]
# *This expression will run the multiplications first and then the addition*

# %%
5 - 2 * 3 ** 4

# %% [markdown]
# *This expression will run the exponent first, then the multiplication, then the subtraction.*

# %%
(5 - 2) * 3 ** 4

# %% [markdown]
# *This expression will run the bracket first, then the exponent, then the multiplication*

# %%
5 + 2 >= 3 * 4

# %% [markdown]
# *This expression will run the multiplication first, then the addition, then the comparison*

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))

# %% [markdown]
# *There is no error here*

# %%
84 *= 0.5 / 7

# %% [markdown]
# *This expression results in a SyntaxError because augmented assignment (*=) cannot be used on a literal value. It must be used on a variable*

# %%
(-(-(-(-5 * (4 + 3)))))

# %% [markdown]
# *There is no error here*

# %%
5 * 3 = weight

# %% [markdown]
# *This expression results in a Syntax Error because you cannot assign the value to the expression (5 * 3).*

# %%
73 / -----------5

# %% [markdown]
# *There is no error here*

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

if isinstance(value, str):
  print("Value is valid")
else:
  raise Exception("Value must be a string")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_23507/3969754771.py in <cell line: 0>()
#       4   print("Value is valid")
#       5 else:
# ----> 6   raise Exception("Value must be a string")
#
# Exception: Value must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])

# %% [markdown]
# *This expression creates an IndexError, the list index is out of range because index 3 does not exist or has not yet been defined/created.*

# %%
fullName = "Taylor Swift"
print(full_name)

# %% [markdown]
# *This expression creates a NameError because "full_name is not defined as the variable name is fullName not full_name"*

# %%
2 + '2' + 4

# %% [markdown]
# *This expression creates a TypeError because of unsupported operand types, you cannot add integers and strings.*

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def km_to_m(km):
  return km / 1.6

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    output = string * num
    return output

# %%
repeat("yesnomaybe", 3)
# Out:
# 'yesnomaybeyesnomaybeyesnomaybe'

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    # remove unwanted characters
    clean = number.replace("(", "").replace(")", "").replace(" ", "").replace("-", "")

    return clean[:3] == "416"

# %%
is_416_number("(416)-555-5555")
# Out:
# True

# %%
is_416_number("514 416 5555")
# Out:
# False

# %%
is_416_number("4165554160")
# Out:
# True
