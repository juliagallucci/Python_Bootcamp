# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5

# %% [markdown]
# Float

# %%
9 / 2

# %% [markdown]
# Float

# %%
1.5 * 2 >= 7 - 3

# %% [markdown]
# boolean

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# (6*3) then (7*4) then the addition of the results

# %%
5 - 2 * 3 ** 4

# %% [markdown]
# *Your answer here*

# %%
(5 - 2) * 3 ** 4

# %% [markdown]
# The brackets 5-2 then the exponentiation 3**4 then the multiplication

# %%
5 + 2 >= 3 * 4

# %% [markdown]
# The multiplication then the addition then the comparision last

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))

# %% [markdown]
# No error

# %%
84 *= 0.5 / 7

# %% [markdown]
# 84 is a number and not a variable so assigning it doesnt make sense and so *= is not well defined

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# Should be no error

# %%
5 * 3 = weight

# %% [markdown]
# assignments should be on the left hand side so weight = .....

# %%
73 / -----------5

# %% [markdown]
# should be fine

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

if isinstance(value, str):
  print("The value is valid")
else:
  print("The value must be a string")
# Out:
# The value must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])

# %% [markdown]
# Indexing starts at 0 so arr has lenght maximal entry 2

# %%
fullName = "Taylor Swift"
print(full_name)

# %% [markdown]
# The variable being printed and the variable defined arent the same

# %%
2 + '2' + 4

# %% [markdown]
# cant add a string to a int they dont mix like that

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def km_to_miles(km):
  return km/1.6

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)

# 3 since answer is globally defined and the one that is inside the scope of the function should not effect anything
# Out:
# 3

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    # your expected output here
    >>> repeat('yesnomaybe', 3)
    # your expected output here
    '''
    output = string * num

    return output
# Out:
# 'yesyesyesyes'

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # Your code goes here
    # Hint: replace () and spaces with nothing
    return "416" == number.replace("(", "").replace(")", "").replace(" ", "")[:3]
# Out:
# True
