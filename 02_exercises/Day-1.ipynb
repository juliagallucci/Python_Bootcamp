# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# Data types involved: integer number or int (8) and floating point number or float (2.5).
# Expression evaluate to: float (20.0)

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# Data types involved: int (9) and int (2). Expression evaluate to: float (4.5)

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# Data types involved: float (1.5), and int (2), int (7), int (3).
# Expression evaluate to: boolean or bool since it produces false

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %% [markdown]
# Multiplication first then addition.

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %% [markdown]
# Exponentiation first, then multiplication, then subtraction.

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# Parentheses first, then exponentiation, then multiplication.

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# Calculation of each side happens first, then comparison operators.

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error. Extra parentheses are fine.

# %%
84 *= 0.5 / 7
# Out:
#   Cell In[9], line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# Error. SyntaxError: 'literal' is an illegal expression for augmented assignment. = is an assignment operator but can't be assigned to a literal number like 84. It needs a variable on the left side.

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No error.

# %%
5 * 3 = weight
# Out:
#   Cell In[11], line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# Error. SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='? This causes an error because variable names in Python cannot start with a digit.

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# No error.

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

if isinstance(value, str):
    print("Value is valid")
else:
    raise Exception("Value must be a string")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 6
#       4     print("Value is valid")
#       5 else:
# ----> 6     raise Exception("Value must be a string")
#
# Exception: Value must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])
#
# IndexError: list index out of range

# %% [markdown]
# IndexError - the list has 3 items at indexes 0, 1, 2. Index 3 doesn't exist.

# %%
fullName = "Taylor Swift"
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 fullName = "Taylor Swift"
# ----> 2 print(full_name)
#
# NameError: name 'full_name' is not defined

# %% [markdown]
# NameError - the variable is named fullName but the code tries to use full_name. These are two different variables.

# %%
2 + '2' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 2 + '2' + 4
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# TypeError - can't add an int and a str together since Python doesn't automatically convert types.

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def km_to_miles(km):
    return km / 1.6

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# 3 is printed. The function answer_to_everything() has its own answer = 42 inside it, but that is a local variable, meaning that it only exists inside the function. The answer = 3 outside the function is a global variable and is unaffected. Therefore, print(answer) prints the global answer which is 3.

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    ''
    >>> repeat('yesnomaybe', 3)
    'yesnomaybeyesnomaybeyesnomaybe'
    '''

    return string * num

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    number = number.replace('(', '').replace(')', '').replace('-', '').replace(' ', '')
    
    return number[:3] == '416'
