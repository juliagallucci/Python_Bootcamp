# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5

# %% [markdown]
# First object is an Int, second is a Float, and the operator is multiplication. The output of this expression will be a Float

# %%
9 / 2

# %% [markdown]
# First object is an Int, second is an Int, and the operator is (non-integer) division. The output of this expression will be a Float

# %%
1.5 * 2 >= 7 - 3

# %% [markdown]
# First object is a Float, others are Ints. Expression will output a Bool.

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4

# %% [markdown]
# Multiplication, then will add the products together.

# %%
5 - 2 * 3 ** 4

# %% [markdown]
# Exponentiation, result of which will be multiplied, then finally subtracted.

# %%
(5 - 2) * 3 ** 4

# %% [markdown]
# Subtraction, then exponentiation, then results will be multiplied together.

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# Multiplication, then addition, then compariason.

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error.

# %%
84 *= 0.5 / 7
# Out:
#   File "/tmp/ipykernel_1950/868797654.py", line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# Syntax error. Cannot apply augmented assignment to a literal object, must be applied to a variable.

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No error.

# %%
5 * 3 = weight
# Out:
#   File "/tmp/ipykernel_1950/3700621706.py", line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# Syntax error. Cannot use this order of varaible assignment, should specify variable name first, then its value.

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# No error.

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

if isinstance(value, str):
  print("Valid")
else:
  raise Exception("Value must be a string")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_1950/2072155805.py in <cell line: 0>()
#       4   print("Valid")
#       5 else:
# ----> 6   raise Exception("Value must be a string")
#
# Exception: Value must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1950/2963248189.py in <cell line: 0>()
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])
#
# IndexError: list index out of range

# %% [markdown]
# Index Error. Array only goes up to index 2 since it has 3 items.

# %%
fullName = "Taylor Swift"
print(full_name)

# %% [markdown]
# Name error. Typo on the print line.

# %%
2 + '2' + 4

# %% [markdown]
# Type error, trying to apply an operator to two different, incomparabel data types.

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def kilometers_to_miles(kilometers: float) -> float:
  """
    Converts kilometers to miles.
    Parameters:
      <kilometers>: distance in km
    Returns:
      distance in miles
  """
  return kilometers / 1.6

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)

# %% [markdown]
# 3

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    ''
    >>> repeat('yesnomaybe', 3)
    'yesnomaybeyesnomaybeyesnomaybe'
    '''
    output = string * num
    return output

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    stripped_number = number.replace('(', '').replace(')', '').replace(' ', '')
    area_code = stripped_number[0:3]
    return(area_code == "416")

is_416_number('(416)-555-5555')
# Out:
# True
