# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# Multiplication operator and 1 integer and 1 floating point operands (8 and 2.5)

# %%
9 / 2

# %% [markdown]
# Division operator and two operands (9 and 2)

# %%
1.5 * 2 >= 7 - 3

# %% [markdown]
# Greater than or equal to Boolean operator, multiplication operator, subtraction operator, and 1 floating point and 3 integer operands

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4

# %% [markdown]
# (6 * 3) + (7 * 4)

# %%
5 - 2 * 3 ** 4

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# (3 ** 4) * (3)

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# False

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error

# %%
84 *= 0.5 / 7
# Out:
#   File "/tmp/ipykernel_5123/868797654.py", line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# This results in a syntax error as the variables can't start with a digit.

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No error here

# %%
5 * 3 = weight
# Out:
#   File "/tmp/ipykernel_5123/3700621706.py", line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# This is a syntax error as variables can't start with a number.

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# No error here.

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

# value = "6"

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])

# %% [markdown]
# the range of digits for the string slicing function is [0:2]

# %%
fullName = "Taylor Swift"
print(full_name)

# %% [markdown]
# the first variable fullName is different from full_name.

# %%
2 + '2' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5123/1647341539.py in <cell line: 0>()
# ----> 1 2 + '2' + 4
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# This is an error because the string is mixed with an integer operand.

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def km_to_miles (miles_distance):
  """
  convert kilometeres to miles given the distance
  Parameters:
  kilometeres (int)
  returns:
  distance in kilometres covnerted into miles
  """
  return (miles_distance / 1.6)

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
#  the answer is 3
# Out:
# 3

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    # your expected output here
    >>> repeat('yesnomaybe', 3)
    # your expected output here
    '''

    return output

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # Your code goes here
    # Hint: replace () and spaces with nothing
