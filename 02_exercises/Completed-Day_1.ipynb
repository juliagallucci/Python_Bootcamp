# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# Operands: Integers (8), Float (2.5)
#
# Operator: Multiplication (*)
#
# Answer: 20.0

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# Operands: Integers (9, 2)
#
# Operator: Division (/)
#
# Answer: 4.5

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# Operands: Integers (2, 7, 3) and Float (1.5)
#
# Operators: Multiplication (*), Subtraction (-), Greater than or equal (>=)
#
# Answer: False

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %% [markdown]
# 1st: 6 * 3
#
# 2nd: 7 * 4
#
# 3rd: 18 + 28

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %% [markdown]
# 1st: 3 ** 4
#
# 2nd: 2 * 3
#
# 3rd: 5 - 162

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# 1st: (5 - 2)
#
# 2nd: 3 ** 4
#
# 3rd: 3 * 81

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# 1st: 5 + 2
#
# 2nd: 3 * 4
#
# 3rd: 7 < 12 (which is False)

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# No error.

# %%
84 *= 0.5 / 7
# Out:
#   File "/tmp/ipykernel_27758/868797654.py", line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# 84 is not valid for this operator *=, because it requires a variable so it can be reassigned a new value each time its multiplied

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# No error

# %%
5 * 3 = weight
# Out:
#   File "/tmp/ipykernel_27758/3700621706.py", line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# Written it backwards, weight should be named first, and assigned the values after

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# No error, --- is triple negatives and will become one negative.

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

def is_string(value):
    """
    Check if the input value is a string.

    Returns: Message if it is or is not a string.
    """
    if type(value) == str:
        print("Valid string")
    else:
        print("Not a string")

# %%
is_string(value)
# Out:
# Not a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_27758/2963248189.py in <cell line: 0>()
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])
#
# IndexError: list index out of range

# %% [markdown]
# List index is out of range, indexes start at 0, so since there's only 3 items, the list index ends at (0, 1, 2).

# %%
fullName = "Taylor Swift"
print(full_name)

# %% [markdown]
# *Your answer here*

# %%
2 + '2' + 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_27758/1647341539.py in <cell line: 0>()
# ----> 1 2 + '2' + 4
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# You cannot add a string '2' with integers.

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def km_to_miles(km):
    """
    Convert kilometers to miles.

    Parameter:
    km (float): The number of kilometers.

    Returns:
    float: The number of miles.
    """

    return km * 0.621371

km_to_miles(10)
# Out:
# 6.21371

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# The code printed a value of 3.

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    ''
    >>> repeat('yesnomaybe', 3)
    'yesnomaybeyesnomaybeyesnomaybe'
    '''

    return string * num

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    number = number.replace('(', '')
    number = number.replace(')', '')
    number = number.replace(' ', '')

    if number[0:3] == '416':
      print(True)
    else:
      print(False)

# %%
is_416_number('(416)-555-5555')
# Out:
# True

# %%
is_416_number('514 416 5555')
# Out:
# False

# %%
is_416_number('4165554160')
# Out:
# True
