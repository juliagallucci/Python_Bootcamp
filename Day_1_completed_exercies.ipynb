# %%
8 * 2.5
#integer and float, data type = float
# Out:
# 20.0

# %%
9 / 2
#integers, data type = float
# Out:
# 4.5

# %%
1.5 * 2 >= 7 - 3
#1.5*2=float, 7-3=integer, data type = boolean
# Out:
# False

# %%
5 * 3 + 7 * 4
#mulitply 6*4, mulitply 7*4, then add results
# Out:
# 43

# %%
5 - 2 * 3 ** 4
#3**4, 2*(result), 5-(result)
# Out:
# -157

# %%
(5-2) * 3 ** 4
#(5-2), 3**4, multiply

# %%
5 + 2 >= 3 * 4
#5+2, 3*4, compare >=

# %%
((((5 * 4 ** 7))))
#no error
# Out:
# 81920

# %%
84 *= 0.5 / 7
#error because a number cannot be a variable

# %%
(-(-(-(-5 * (4 + 3)))))
#no error

# %%
5 * 3 = weight
#error because this is written backwards

# %%
73 / ----------5
#error because there are to many - (not a valid number or operation)

# %%
value = 6
if type(value) == str:
  print("Value is a valid")
else: Exception("value must be a string")

# %%
arr = [1,2,3]
print(arr[3])
#the list only has 0,1,2

# %%
fullName = "Taylor Swift"
print(full_name)
#the variable is not defined correctly

# %%
2 + '2' + 4
#cannot mix integer and string

# %%
def km_to_miles(km):
  return km / 1.6

# %%
answer = 3
def answer_to_everything():
  '''Return the answer to life, the universe, and everything'''
  answer = 42
  return answer
  answer_to_everything()
  #print(answer) = 3

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    # your expected output here
    >>> repeat('yesnomaybe', 3)
    # your expected output here
    '''

    return string * num

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    return number [0:3] == "416"
